# %% [markdown]
# ### pandas : DataFrame.apply()메서드 사용해보기

# %%
import pandas as pd

titanic_df = pd.read_csv('titanic_train.csv')
titanic_df['by_10'] = titanic_df['Age'].apply(lambda x : x * 10)

print(titanic_df['Age'])
print(titanic_df['by_10'])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
# 0      220.0
# 1      380.0
# 2      260.0
# 3      350.0
# 4      350.0
#        ...
# 886    270.0
# 887    190.0
# 888      NaN
# 889    260.0
# 890    320.0
# Name: by_10, Length: 891, dtype: float64
