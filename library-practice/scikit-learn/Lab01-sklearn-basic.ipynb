# %% [markdown]
# # Scikit Learn : Python ML Library
# * sklearn을 이용한 ML의 전체 흐름
# 	1. 데이터 전처리 후 데이터 세트 분리
# 	2. `model.fit()`을 이용한 모델 학습
# 	3. `model.predict()`를 이용한 예측
# 	4. Metric을 이용한 예측 성능 평가

# %% [markdown]
# ### Practice : load iris data and convert to DataFrame

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

# feature data 추출
iris_data = iris.data # print(type(iris_data)) : numpy.ndarray
# 레이블(결정값) data 추출
iris_label = iris.target # print(type(iris_label)) : numpy.ndarray

iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['label'] = iris.target

# %% [markdown]
# ### Practice : split all data to training dataset, test dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris_data, iris_label, test_size=0.2, random_state=11)

# %% [markdown]
# ### Practice : training and test DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt_clf = DecisionTreeClassifier(random_state=11)
dt_clf.fit(X_train, y_train)

pred = dt_clf.predict(X_test)

# %% [markdown]
# ### Practice : Accuracy기반 모델 평가

# %%
from sklearn.metrics import accuracy_score

print('예측 정확도 : {0:.4f}'.format(accuracy_score(y_test,pred)))
# Out:
# 예측 정확도 : 0.9333
